# %% [markdown]
# !pip install --upgrade tensorflow

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/Alcohol_Sales.csv', index_col='DATE',parse_dates=True)
df.index.freg = 'MS'

# %%
df.head()
# Out:
#             S4248SM144NCEN
# DATE
# 1992-01-01            3459
# 1992-02-01            3458
# 1992-03-01            4002
# 1992-04-01            4564
# 1992-05-01            4221

# %%
df.columns = ['Sale']

# %%
df
# Out:
#              Sale
# DATE
# 1992-01-01   3459
# 1992-02-01   3458
# 1992-03-01   4002
# 1992-04-01   4564
# 1992-05-01   4221
# ...           ...
# 2018-09-01  12396
# 2018-10-01  13914
# 2018-11-01  14174
# 2018-12-01  15504
# 2019-01-01  10718
#
# [325 rows x 1 columns]

# %% [markdown]
# ## Train test

# %%
len(df)
# Out:
# 325

# %%
325-12
# Out:
# 313

# %%
train = df.iloc[:313]
test = df.iloc[313:]

# %%
len(test)
# Out:
# 12

# %% [markdown]
# # scale data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(train)
# Out:
# MinMaxScaler()

# %%
MinMaxScaler(copy=True, feature_range=(0,1))
# Out:
# MinMaxScaler()

# %%
scaler_train = scaler.transform(train)
scaler_test = scaler.transform(test)

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
scaler_train
# Out:
# array([[0.03658432],
#        [0.03649885],
#        [0.08299855],
#        [0.13103684],
#        [0.1017181 ],
#        [0.12804513],
#        [0.12266006],
#        [0.09453799],
#        [0.09359774],
#        [0.10496624],
#        [0.10334217],
#        [0.16283443],
#        [0.        ],
#        [0.0196598 ],
#        [0.09650397],
#        [0.11505257],
#        [0.10906915],
#        [0.14231986],
#        [0.12197624],
#        [0.12189076],
#        [0.11394136],
#        [0.10300026],
#        [0.12556629],
#        [0.16608257],
#        [0.00376101],
#        [0.02957518],
#        [0.12069408],
#        [0.10513719],
#        [0.12214719],
#        [0.16702282],
#        [0.11052227],
#        [0.14428584],
#        [0.11479614],
#        [0.10402599],
#        [0.14984187],
#        [0.16582614],
#        [0.02897684],
#        [0.03872126],
#        [0.10582101],
#        [0.08231473],
#        [0.14394393],
#        [0.16608257],
#        [0.10188905],
# ...

# %%
n_input = 2
n_features = 1
generator = TimeseriesGenerator(scaler_train, scaler_train, length=n_input, batch_size = 1)

# %%
len(scaler_train)
# Out:
# 313

# %%
len(generator)
# Out:
# 311

# %%
scaler_train
# Out:
# array([[0.03658432],
#        [0.03649885],
#        [0.08299855],
#        [0.13103684],
#        [0.1017181 ],
#        [0.12804513],
#        [0.12266006],
#        [0.09453799],
#        [0.09359774],
#        [0.10496624],
#        [0.10334217],
#        [0.16283443],
#        [0.        ],
#        [0.0196598 ],
#        [0.09650397],
#        [0.11505257],
#        [0.10906915],
#        [0.14231986],
#        [0.12197624],
#        [0.12189076],
#        [0.11394136],
#        [0.10300026],
#        [0.12556629],
#        [0.16608257],
#        [0.00376101],
#        [0.02957518],
#        [0.12069408],
#        [0.10513719],
#        [0.12214719],
#        [0.16702282],
#        [0.11052227],
#        [0.14428584],
#        [0.11479614],
#        [0.10402599],
#        [0.14984187],
#        [0.16582614],
#        [0.02897684],
#        [0.03872126],
#        [0.10582101],
#        [0.08231473],
#        [0.14394393],
#        [0.16608257],
#        [0.10188905],
# ...

# %%
# what does the first batch looklike?
X,y = generator[0]

# %%
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.03658432 0.03649885]
# Predict this y:
#  [[0.08299855]]

# %%
n_input = 12
generator = TimeseriesGenerator(scaler_train, scaler_train, length=n_input, batch_size=1)

# %%
X,y = generator[0]

# %%
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.03658432 0.03649885 0.08299855 0.13103684 0.1017181  0.12804513
#  0.12266006 0.09453799 0.09359774 0.10496624 0.10334217 0.16283443]
# Predict this y:
#  [[0.]]

# %% [markdown]
# # create the model

# %%
from keras.models import Sequential
from keras.layers import Dense  # Đúng cách nhập Dense
from keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100)                 │          40,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 40,901 (159.77 KB)
#  Trainable params: 40,901 (159.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(generator, epochs=50)
# Out:
# Epoch 1/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0458
# Epoch 2/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0082
# Epoch 3/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0065
# Epoch 4/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0073
# Epoch 5/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0060
# Epoch 6/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0068
# Epoch 7/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0049
# Epoch 8/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0040
# Epoch 9/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0032
# Epoch 10/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0031
# Epoch 11/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0029
# Epoch 12/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0027
# Epoch 13/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0021
# Epoch 14/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0021
# ...

# %%
model.history.history.keys()
# Out:
# dict_keys(['loss'])

# %%
loss_per_epoch = model.history.history['loss']

# Vẽ biểu đồ loss qua các epoch
plt.plot(range(len(loss_per_epoch)), loss_per_epoch)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss per Epoch')
plt.show()

# %% [markdown]
# # Evaluete on test data

# %%
first_eval_batch = scaler_train[-12:]

# %%
first_eval_batch
# Out:
# array([[0.63432772],
#        [0.80776135],
#        [0.72313873],
#        [0.89870929],
#        [1.        ],
#        [0.71672793],
#        [0.88648602],
#        [0.75869732],
#        [0.82742115],
#        [0.87443371],
#        [0.96025301],
#        [0.5584238 ]])

# %%
first_eval_batch = first_eval_batch.reshape((1, n_input, n_features))

# %%
model.predict(first_eval_batch)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step
# array([[0.69293535]], dtype=float32)

# %%
scaler_test[0]
# Out:
# array([0.63116506])

# %%
test_predictions = []
first_eval_batch = first_eval_batch.reshape((1, n_input, n_features))

# %%
current_batch.shape
# Out:
# (1, 12, 1)

# %%
current_batch
# Out:
# array([[[0.03658432],
#         [0.03649885],
#         [0.08299855],
#         [0.13103684],
#         [0.1017181 ],
#         [0.12804513],
#         [0.12266006],
#         [0.09453799],
#         [0.09359774],
#         [0.10496624],
#         [0.10334217],
#         [0.16283443]]])

# %%
np.append(current_batch[:,1:,:],[[[99]]],axis=1)
# Out:
# array([[[3.64988461e-02],
#         [8.29985469e-02],
#         [1.31036841e-01],
#         [1.01718096e-01],
#         [1.28045132e-01],
#         [1.22660056e-01],
#         [9.45379947e-02],
#         [9.35977434e-02],
#         [1.04966236e-01],
#         [1.03342166e-01],
#         [1.62834430e-01],
#         [9.90000000e+01]]])

# %% [markdown]
# # going

# %%
# Holding predictions
test_predictions = []

# Last n_input points from the training set
first_eval_batch = scaler_train[-n_input:]

# Reshape this to the format RNN wants (same format as TimeseriesGenerator)
current_batch = first_eval_batch.reshape((1, n_input, n_features))

# How far into the future will you forecast?
for i in range(len(test)):

    # Get prediction 1-time step ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]

    # Store prediction
    test_predictions.append(current_pred)

    # Update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step

# %%
test_predictions
# Out:
# [array([0.69293535], dtype=float32),
#  array([0.8169471], dtype=float32),
#  array([0.7716427], dtype=float32),
#  array([0.9383582], dtype=float32),
#  array([1.0177083], dtype=float32),
#  array([0.75339127], dtype=float32),
#  array([0.9140786], dtype=float32),
#  array([0.76881623], dtype=float32),
#  array([0.85415745], dtype=float32),
#  array([0.8968594], dtype=float32),
#  array([0.98043], dtype=float32),
#  array([0.58275187], dtype=float32)]

# %%
scaler_test
# Out:
# array([[0.63116506],
#        [0.82502778],
#        [0.75972305],
#        [0.94939738],
#        [0.98743482],
#        [0.82135225],
#        [0.95956919],
#        [0.80049577],
#        [0.93025045],
#        [0.95247457],
#        [1.0661595 ],
#        [0.65706471]])

# %%
# Inverse Transformations and Compare
true_predictions = scaler.inverse_transform(test_predictions)

# %%
# Display the true_predictions
true_predictions
# Out:
# array([[11137.65063107],
#        [12588.46415269],
#        [12058.44777107],
#        [14008.85243762],
#        [14937.16941977],
#        [11844.9244194 ],
#        [13724.80546248],
#        [12025.38110614],
#        [13023.78798199],
#        [13523.35820746],
#        [14501.05065167],
#        [ 9848.61412895]])

# %%
test
# Out:
#              Sale
# DATE
# 2018-02-01  10415
# 2018-03-01  12683
# 2018-04-01  11919
# 2018-05-01  14138
# 2018-06-01  14583
# 2018-07-01  12640
# 2018-08-01  14257
# 2018-09-01  12396
# 2018-10-01  13914
# 2018-11-01  14174
# 2018-12-01  15504
# 2019-01-01  10718

# %%
test['prediction']=true_predictions

# %%
test
# Out:
#              Sale    prediction
# DATE
# 2018-02-01  10415  11137.650631
# 2018-03-01  12683  12588.464153
# 2018-04-01  11919  12058.447771
# 2018-05-01  14138  14008.852438
# 2018-06-01  14583  14937.169420
# 2018-07-01  12640  11844.924419
# 2018-08-01  14257  13724.805462
# 2018-09-01  12396  12025.381106
# 2018-10-01  13914  13023.787982
# 2018-11-01  14174  13523.358207
# 2018-12-01  15504  14501.050652
# 2019-01-01  10718   9848.614129

# %%
test.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
# Saving and Loading Models

# Save the model
model.save('my_rnn_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.metrics import MeanSquaredError

# Khi tải mô hình, truyền tham số `custom_objects`
new_model = load_model('my_rnn_model.h5', custom_objects={'mse': MeanSquaredError()})
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Display the model summary
new_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 100)                 │          40,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 40,903 (159.78 KB)
#  Trainable params: 40,901 (159.77 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)
